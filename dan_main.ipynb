# %%
import argparse
import time
import numpy as np
from math import ceil
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder

import torch
import torch.nn.functional as F
from torch import optim

# from model import RW_NN
from utils import load_data, generate_batches, accuracy, AverageMeter

# %%
# THE MODEL
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.autograd import Variable
from torch.nn.parameter import Parameter

class RW_NN(nn.Module):
    # new hyperparameters
    # max_num_children
    def __init__(self, input_dim, max_step, hidden_graphs, size_hidden_graphs, hidden_dim, penultimate_dim, normalize, n_classes, dropout, device):
        super(RW_NN, self).__init__()
        self.max_step = max_step
        self.hidden_graphs = hidden_graphs
        self.size_hidden_graphs = size_hidden_graphs
        self.normalize = normalize
        self.device = device
        self.adj_hidden = Parameter(torch.FloatTensor(hidden_graphs, (size_hidden_graphs*(size_hidden_graphs-1))//2))
        self.features_hidden = Parameter(torch.FloatTensor(hidden_graphs, size_hidden_graphs, hidden_dim))
        self.fc = torch.nn.Linear(input_dim, hidden_dim)
        self.bn = nn.BatchNorm1d(hidden_graphs*max_step)
        self.fc1 = torch.nn.Linear(hidden_graphs*max_step, penultimate_dim)
        self.fc2 = torch.nn.Linear(penultimate_dim, n_classes)
        self.dropout = nn.Dropout(p=dropout)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()
        self.init_weights()

    def init_weights(self):
        self.adj_hidden.data.uniform_(-1, 1)
        self.features_hidden.data.uniform_(0, 1)

        
    def forward(self, adj, features, graph_indicator):
        unique, counts = torch.unique(graph_indicator, return_counts=True)
        n_graphs = unique.size(0)
        n_nodes = features.size(0)

        if self.normalize:
            norm = counts.unsqueeze(1).repeat(1, self.hidden_graphs)
        
        adj_hidden_norm = torch.zeros(self.hidden_graphs, self.size_hidden_graphs, self.size_hidden_graphs).to(self.device)
        idx = torch.triu_indices(self.size_hidden_graphs, self.size_hidden_graphs, 1)
        adj_hidden_norm[:,idx[0],idx[1]] = self.relu(self.adj_hidden)
        adj_hidden_norm = adj_hidden_norm + torch.transpose(adj_hidden_norm, 1, 2)
        x = self.sigmoid(self.fc(features))
        z = self.features_hidden
        zx = torch.einsum("abc,dc->abd", (z, x))
        
        out = list()
        for i in range(self.max_step):
            if i == 0:
                eye = torch.eye(self.size_hidden_graphs, device=self.device)
                eye = eye.repeat(self.hidden_graphs, 1, 1)              
                o = torch.einsum("abc,acd->abd", (eye, z))
                t = torch.einsum("abc,dc->abd", (o, x))
            else:
                x = torch.spmm(adj, x)
                z = torch.einsum("abc,acd->abd", (adj_hidden_norm, z))
                t = torch.einsum("abc,dc->abd", (z, x))
            t = self.dropout(t)
            t = torch.mul(zx, t)
            t = torch.zeros(t.size(0), t.size(1), n_graphs, device=self.device).index_add_(2, graph_indicator, t)
            t = torch.sum(t, dim=1)
            t = torch.transpose(t, 0, 1)
            if self.normalize:
                t /= norm
            out.append(t)
            
        out = torch.cat(out, dim=1)
        out = self.bn(out)
        out = self.relu(self.fc1(out))
        out = self.dropout(out)
        out = self.fc2(out)
        return F.log_softmax(out, dim=1)
    def get_hidden_graphs_adjacency_list(self):
        """Converts the upper-triangular adjacency data to adjacency lists."""
        adj_hidden_norm = torch.zeros(self.hidden_graphs, self.size_hidden_graphs, self.size_hidden_graphs).to(self.device)
        idx = torch.triu_indices(self.size_hidden_graphs, self.size_hidden_graphs, 1)
        adj_hidden_norm[:, idx[0], idx[1]] = self.relu(self.adj_hidden)
        adj_hidden_norm = adj_hidden_norm + torch.transpose(adj_hidden_norm, 1, 2)
        
        # Convert each hidden graph's adjacency matrix to an adjacency list
        adjacency_lists = []
        for i in range(self.hidden_graphs):
            adj_list = {}
            adj_matrix = adj_hidden_norm[i].detach().cpu().numpy()  # Move to CPU for easy processing
            for row in range(adj_matrix.shape[0]):
                adj_list[row] = list(np.where(adj_matrix[row] > 0)[0])  # Find connected nodes
            adjacency_lists.append(adj_list)
        
        return adjacency_lists

# %%
# settings
from types import SimpleNamespace
args = SimpleNamespace(
    dataset='synthetic',
    use_node_labels=False,
    lr=1e-2,
    dropout=0.2,
    batch_size=64,
    epochs=5,
    hidden_graphs=16,
    size_hidden_graphs=5,
    hidden_dim=4,
    penultimate_dim=32,
    max_step=2,
    normalize=False,
)

# %%
import matplotlib.pyplot as plt
import networkx as nx
import random

open("graph_A.txt", "w").close()

open("graph_indicator.txt", "w").close()
open("graph_labels.txt", "w").close()
graph_indicator = 1
random_num = random.randint(5, 30)
random_graphs = []
for _ in range(25):
    n = random_num  # 10 nodes
    m = random_num  # 20 edges
    # seed = 42  # seed random number generators for reproducibility

    # Use seed for reproducibility
    G = nx.gnm_random_graph(n, m)
    random_graphs.append(G)
    # some properties
    # print("node degree clustering")
    # for v in nx.nodes(G):
    #     print(f"{v} {nx.degree(G, v)} {nx.clustering(G, v)}")

    # print()
    print(nx.generate_adjlist(G))
    pairs = []

    for line in nx.generate_adjlist(G):
        # Split the line into nodes
        nodes = line.split()
        # The first node is the source, and the rest are targets
        source = nodes[0]
        targets = nodes[1:]
        
        # Generate (source, target) pairs
        for target in targets:
            print(str(int(source) + 1))
            pairs.append((str(int(source) + 1), str(int(target) + 1)))
    print(pairs)
    # Write the result to a file
    with open("graph_A.txt", "a") as f:
        for pair in pairs:
            f.write(f"{pair[0]}, {pair[1]}\n")

    with open("graph_indicator.txt", "a") as f:
        for pair in pairs:
            f.write(f"{graph_indicator}\n")
    with open("graph_labels.txt", "a") as f:
        f.write(f"0\n")
        graph_indicator += 1
# Out:
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 2
# 2
# 2
# [('1', '2'), ('1', '5'), ('2', '5'), ('2', '3'), ('2', '4')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 2
# 3
# 3
# [('1', '2'), ('1', '5'), ('2', '3'), ('3', '4'), ('3', '5')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 2
# 2
# 4
# [('1', '4'), ('1', '5'), ('2', '3'), ('2', '4'), ('4', '5')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 1
# 2
# 3
# [('1', '3'), ('1', '5'), ('1', '4'), ('2', '4'), ('3', '5')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 2
# 3
# 3
# 4
# [('1', '5'), ('2', '5'), ('3', '4'), ('3', '5'), ('4', '5')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 2
# 2
# 3
# [('1', '4'), ('1', '3'), ('2', '4'), ('2', '5'), ('3', '5')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 2
# 3
# 4
# [('1', '4'), ('1', '3'), ('2', '4'), ('3', '5'), ('4', '5')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 2
# 3
# 3
# [('1', '5'), ('1', '2'), ('2', '5'), ('3', '5'), ('3', '4')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 1
# 2
# 3
# [('1', '3'), ('1', '5'), ('1', '2'), ('2', '3'), ('3', '4')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 2
# 2
# 3
# [('1', '5'), ('1', '4'), ('2', '5'), ('2', '4'), ('3', '4')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 2
# 3
# 4
# [('1', '4'), ('1', '3'), ('2', '3'), ('3', '4'), ('4', '5')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 2
# 2
# 3
# 4
# [('1', '4'), ('2', '4'), ('2', '3'), ('3', '4'), ('4', '5')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 2
# 2
# 4
# [('1', '5'), ('1', '3'), ('2', '3'), ('2', '4'), ('4', '5')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 1
# 2
# 3
# [('1', '2'), ('1', '5'), ('1', '3'), ('2', '3'), ('3', '5')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 2
# 2
# 3
# 4
# [('1', '2'), ('2', '4'), ('2', '5'), ('3', '5'), ('4', '5')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 2
# 2
# 3
# [('1', '2'), ('1', '5'), ('2', '5'), ('2', '4'), ('3', '4')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 2
# 3
# 4
# [('1', '4'), ('1', '3'), ('2', '4'), ('3', '4'), ('4', '5')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 2
# 3
# 3
# 4
# [('1', '5'), ('2', '5'), ('3', '4'), ('3', '5'), ('4', '5')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 2
# 2
# 3
# 4
# [('1', '5'), ('2', '3'), ('2', '5'), ('3', '5'), ('4', '5')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 1
# 2
# 3
# [('1', '3'), ('1', '5'), ('1', '4'), ('2', '3'), ('3', '4')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 3
# 3
# 4
# [('1', '2'), ('1', '5'), ('3', '5'), ('3', '4'), ('4', '5')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 2
# 2
# 4
# [('1', '4'), ('1', '3'), ('2', '4'), ('2', '3'), ('4', '5')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 2
# 3
# 3
# [('1', '4'), ('1', '5'), ('2', '5'), ('3', '5'), ('3', '4')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 1
# 3
# 3
# [('1', '4'), ('1', '5'), ('1', '3'), ('3', '5'), ('3', '4')]
# <generator object generate_adjlist at 0x000002727990F7D8>
# 1
# 1
# 2
# 3
# 4
# [('1', '2'), ('1', '5'), ('2', '5'), ('3', '4'), ('4', '5')]

# %%
import matplotlib.pyplot as plt
import networkx as nx
import random
   
random_num = random.randint(5, 30)
random_graphs = []
for _ in range(25):
    n = random_num  # 10 nodes
    m = random_num  # 20 edges
    # seed = 42  # seed random number generators for reproducibility

    # Use seed for reproducibility
    G = nx.cycle_graph(n)
    random_graphs.append(G)
    # some properties
    # print("node degree clustering")
    # for v in nx.nodes(G):
    #     print(f"{v} {nx.degree(G, v)} {nx.clustering(G, v)}")

    # print()
    pairs = []

    for line in nx.generate_adjlist(G):
        # Split the line into nodes
        nodes = line.split()
        # The first node is the source, and the rest are targets
        source = nodes[0]
        targets = nodes[1:]
        
        # Generate (source, target) pairs
        for target in targets:
            pairs.append((str(int(source) + 1), str(int(target) + 1)))
        
    # Write the result to a file
    with open("graph_A.txt", "a") as f:
        for pair in pairs:
            f.write(f"{pair[0]}, {pair[1]}\n")
    with open("graph_indicator.txt", "a") as f:
        for pair in pairs:
            f.write(f"{graph_indicator}\n")
    with open("graph_labels.txt", "a") as f:
        f.write(f"1\n")
        graph_indicator += 1

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
adj_lst, features_lst, class_labels = load_data(args.dataset, args.use_node_labels)

N = len(adj_lst)
features_dim = features_lst[0].shape[1]

enc = LabelEncoder()
class_labels = enc.fit_transform(class_labels)
n_classes = np.unique(class_labels).size
y = [np.array(class_labels[i]) for i in range(class_labels.size)]

kf = KFold(n_splits=10, shuffle=True, random_state=13)
it = 0
accs = list()

# %%
for train_index, test_index in kf.split(y):
    it += 1
    
    idx = np.random.permutation(train_index)
    train_index = idx[:int(idx.size*0.9)].tolist()
    val_index = idx[int(idx.size*0.9):].tolist()

    n_train = len(train_index)
    n_val = len(val_index)
    n_test = len(test_index)

    adj_train = [adj_lst[i] for i in train_index]
    features_train = [features_lst[i] for i in train_index]
    y_train = [y[i] for i in train_index]

    adj_val = [adj_lst[i] for i in val_index]
    features_val = [features_lst[i] for i in val_index]
    y_val = [y[i] for i in val_index]

    adj_test = [adj_lst[i] for i in test_index]
    features_test = [features_lst[i] for i in test_index]
    y_test = [y[i] for i in test_index]

    adj_train, features_train, graph_indicator_train, y_train = generate_batches(adj_train, features_train, y_train, args.batch_size, device)
    adj_val, features_val, graph_indicator_val, y_val = generate_batches(adj_val, features_val, y_val, args.batch_size, device)
    adj_test, features_test, graph_indicator_test, y_test = generate_batches(adj_test, features_test, y_test, args.batch_size, device)

    n_train_batches = ceil(n_train/args.batch_size)
    n_val_batches = ceil(n_val/args.batch_size)
    n_test_batches = ceil(n_test/args.batch_size)
    
    model = RW_NN(features_dim, args.max_step, args.hidden_graphs, args.size_hidden_graphs, args.hidden_dim, args.penultimate_dim, args.normalize, n_classes, args.dropout, device).to(device)
    optimizer = optim.Adam(model.parameters(), lr=args.lr)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.5)

    def train(epoch, adj, features, graph_indicator, y):
        optimizer.zero_grad()
        output = model(adj, features, graph_indicator)
        loss_train = F.cross_entropy(output, y)
        loss_train.backward()
        optimizer.step()
        return output, loss_train

    def test(adj, features, graph_indicator, y):
        output = model(adj, features, graph_indicator)
        loss_test = F.cross_entropy(output, y)
        return output, loss_test

    best_acc = 0

    for epoch in range(args.epochs):
        start = time.time()
        model.train()
        train_loss = AverageMeter()
        train_acc = AverageMeter()

        # Train for one epoch
        for i in range(n_train_batches):
            output, loss = train(epoch, adj_train[i], features_train[i], graph_indicator_train[i], y_train[i])
            train_loss.update(loss.item(), output.size(0))
            train_acc.update(accuracy(output.data, y_train[i].data), output.size(0))

        # Evaluate on validation set
        model.eval()
        val_loss = AverageMeter()
        val_acc = AverageMeter()

        for i in range(n_val_batches):
            output, loss = test(adj_val[i], features_val[i], graph_indicator_val[i], y_val[i])
            val_loss.update(loss.item(), output.size(0))
            val_acc.update(accuracy(output.data, y_val[i].data), output.size(0))

        scheduler.step()
        
        # Print results
        print("Cross-val iter:", '%02d' % it, "epoch:", '%03d' % (epoch + 1), "train_loss=", "{:.5f}".format(train_loss.avg),
            "train_acc=", "{:.5f}".format(train_acc.avg), "val_loss=", "{:.5f}".format(val_loss.avg),
            "val_acc=", "{:.5f}".format(val_acc.avg), "time=", "{:.5f}".format(time.time() - start))
        
        # Remember best accuracy and save checkpoint
        is_best = val_acc.avg >= best_acc
        best_acc = max(val_acc.avg, best_acc)
        if is_best:
            early_stopping_counter = 0
            torch.save({
                'epoch': epoch + 1,
                'state_dict': model.state_dict(),
                'optimizer' : optimizer.state_dict(),
            }, 'model_best.pth.tar')

    print("Optimization finished!")

    # Testing
    test_loss = AverageMeter()
    test_acc = AverageMeter()
    print("Loading checkpoint!")
    checkpoint = torch.load('model_best.pth.tar')
    epoch = checkpoint['epoch']
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    
    for i in range(n_test_batches):
        output, loss = test(adj_test[i], features_test[i], graph_indicator_test[i], y_test[i])
        test_loss.update(loss.item(), output.size(0))
        test_acc.update(accuracy(output.data, y_test[i].data), output.size(0))
    accs.append(test_acc.avg.cpu().numpy())

    # Print results
    print("test_loss=", "{:.5f}".format(test_loss.avg), "test_acc=", "{:.5f}".format(test_acc.avg))
    print()
    
print("avg_test_acc=", "{:.5f}".format(np.mean(accs)))
# Out:
# Cross-val iter: 01 epoch: 001 train_loss= 0.67324 train_acc= 0.55000 val_loss= 8.39358 val_acc= 0.60000 time= 0.03644
# Cross-val iter: 01 epoch: 002 train_loss= 0.72280 train_acc= 0.40000 val_loss= 5.77755 val_acc= 0.60000 time= 0.01383
# Cross-val iter: 01 epoch: 003 train_loss= 0.71961 train_acc= 0.45000 val_loss= 4.28453 val_acc= 0.60000 time= 0.01552
# Cross-val iter: 01 epoch: 004 train_loss= 0.73502 train_acc= 0.40000 val_loss= 2.70413 val_acc= 0.60000 time= 0.01662
# Cross-val iter: 01 epoch: 005 train_loss= 0.72613 train_acc= 0.40000 val_loss= 1.45737 val_acc= 0.60000 time= 0.01553
# Optimization finished!
# Loading checkpoint!
# test_loss= 232.56360 test_acc= 0.40000
#
# Cross-val iter: 02 epoch: 001 train_loss= 0.74347 train_acc= 0.45000 val_loss= 0.67489 val_acc= 0.60000 time= 0.01609
# Cross-val iter: 02 epoch: 002 train_loss= 0.67406 train_acc= 0.47500 val_loss= 0.67405 val_acc= 0.60000 time= 0.02246
# Cross-val iter: 02 epoch: 003 train_loss= 0.67233 train_acc= 0.60000 val_loss= 0.67562 val_acc= 0.60000 time= 0.01333
# Cross-val iter: 02 epoch: 004 train_loss= 0.67263 train_acc= 0.57500 val_loss= 0.67505 val_acc= 0.60000 time= 0.01536
# Cross-val iter: 02 epoch: 005 train_loss= 0.67878 train_acc= 0.55000 val_loss= 0.67348 val_acc= 0.60000 time= 0.01486
# Optimization finished!
# Loading checkpoint!
# test_loss= 0.67348 test_acc= 0.60000
#
# Cross-val iter: 03 epoch: 001 train_loss= 0.67818 train_acc= 0.60000 val_loss= 4.94164 val_acc= 0.40000 time= 0.01279
# Cross-val iter: 03 epoch: 002 train_loss= 0.66487 train_acc= 0.62500 val_loss= 3.59403 val_acc= 0.40000 time= 0.00709
# Cross-val iter: 03 epoch: 003 train_loss= 0.69369 train_acc= 0.40000 val_loss= 3.14607 val_acc= 0.40000 time= 0.01267
# Cross-val iter: 03 epoch: 004 train_loss= 0.67466 train_acc= 0.47500 val_loss= 2.69480 val_acc= 0.40000 time= 0.00596
# Cross-val iter: 03 epoch: 005 train_loss= 0.67077 train_acc= 0.57500 val_loss= 2.36396 val_acc= 0.40000 time= 0.01362
# Optimization finished!
# Loading checkpoint!
# test_loss= 1.58261 test_acc= 0.60000
#
# Cross-val iter: 04 epoch: 001 train_loss= 0.70059 train_acc= 0.50000 val_loss= 2.59656 val_acc= 0.40000 time= 0.01231
# Cross-val iter: 04 epoch: 002 train_loss= 0.66362 train_acc= 0.60000 val_loss= 1.58154 val_acc= 0.40000 time= 0.02021
# Cross-val iter: 04 epoch: 003 train_loss= 0.64160 train_acc= 0.70000 val_loss= 1.53912 val_acc= 0.40000 time= 0.01680
# Cross-val iter: 04 epoch: 004 train_loss= 0.69715 train_acc= 0.52500 val_loss= 1.63983 val_acc= 0.40000 time= 0.01251
# Cross-val iter: 04 epoch: 005 train_loss= 0.67347 train_acc= 0.67500 val_loss= 1.24329 val_acc= 0.40000 time= 0.01651
# Optimization finished!
# Loading checkpoint!
# test_loss= 1.24329 test_acc= 0.40000
#
# Cross-val iter: 05 epoch: 001 train_loss= 0.83777 train_acc= 0.45000 val_loss= 2.32470 val_acc= 0.80000 time= 0.01861
# Cross-val iter: 05 epoch: 002 train_loss= 0.75741 train_acc= 0.45000 val_loss= 1.37780 val_acc= 0.80000 time= 0.01651
# Cross-val iter: 05 epoch: 003 train_loss= 0.70192 train_acc= 0.47500 val_loss= 0.91490 val_acc= 0.80000 time= 0.01493
# Cross-val iter: 05 epoch: 004 train_loss= 0.67881 train_acc= 0.47500 val_loss= 0.62079 val_acc= 0.80000 time= 0.01613
# Cross-val iter: 05 epoch: 005 train_loss= 0.67301 train_acc= 0.50000 val_loss= 0.50082 val_acc= 0.80000 time= 0.01710
# Optimization finished!
# Loading checkpoint!
# test_loss= 0.79254 test_acc= 0.60000
#
# Cross-val iter: 06 epoch: 001 train_loss= 0.70952 train_acc= 0.47500 val_loss= 2.03261 val_acc= 0.80000 time= 0.02326
# Cross-val iter: 06 epoch: 002 train_loss= 0.67756 train_acc= 0.60000 val_loss= 1.22597 val_acc= 0.80000 time= 0.01378
# Cross-val iter: 06 epoch: 003 train_loss= 0.68463 train_acc= 0.45000 val_loss= 0.76709 val_acc= 0.80000 time= 0.01873
# Cross-val iter: 06 epoch: 004 train_loss= 0.67544 train_acc= 0.55000 val_loss= 0.66571 val_acc= 0.80000 time= 0.01101
# Cross-val iter: 06 epoch: 005 train_loss= 0.69012 train_acc= 0.55000 val_loss= 0.61510 val_acc= 0.80000 time= 0.00988
# Optimization finished!
# Loading checkpoint!
# test_loss= 1.72403 test_acc= 0.40000
#
# Cross-val iter: 07 epoch: 001 train_loss= 0.71414 train_acc= 0.52500 val_loss= 5.91232 val_acc= 0.20000 time= 0.01690
# Cross-val iter: 07 epoch: 002 train_loss= 0.68201 train_acc= 0.55000 val_loss= 5.67322 val_acc= 0.20000 time= 0.01401
# Cross-val iter: 07 epoch: 003 train_loss= 0.66821 train_acc= 0.55000 val_loss= 5.35258 val_acc= 0.20000 time= 0.01230
# Cross-val iter: 07 epoch: 004 train_loss= 0.67629 train_acc= 0.55000 val_loss= 4.94073 val_acc= 0.20000 time= 0.01931
# Cross-val iter: 07 epoch: 005 train_loss= 0.67953 train_acc= 0.57500 val_loss= 4.48280 val_acc= 0.20000 time= 0.02056
# Optimization finished!
# Loading checkpoint!
# test_loss= 3.36302 test_acc= 0.40000
#
# Cross-val iter: 08 epoch: 001 train_loss= 0.69193 train_acc= 0.57500 val_loss= 0.68817 val_acc= 0.60000 time= 0.01176
# Cross-val iter: 08 epoch: 002 train_loss= 0.67286 train_acc= 0.57500 val_loss= 0.73410 val_acc= 0.40000 time= 0.01606
# Cross-val iter: 08 epoch: 003 train_loss= 0.67458 train_acc= 0.55000 val_loss= 0.87308 val_acc= 0.40000 time= 0.01325
# Cross-val iter: 08 epoch: 004 train_loss= 0.67828 train_acc= 0.52500 val_loss= 0.98426 val_acc= 0.40000 time= 0.01270
# Cross-val iter: 08 epoch: 005 train_loss= 0.67366 train_acc= 0.57500 val_loss= 1.03098 val_acc= 0.40000 time= 0.01008
# Optimization finished!
# Loading checkpoint!
# test_loss= 0.68817 test_acc= 0.60000
#
# Cross-val iter: 09 epoch: 001 train_loss= 0.68003 train_acc= 0.55000 val_loss= 0.79617 val_acc= 0.40000 time= 0.01211
# Cross-val iter: 09 epoch: 002 train_loss= 0.67370 train_acc= 0.60000 val_loss= 0.68336 val_acc= 0.60000 time= 0.01771
# Cross-val iter: 09 epoch: 003 train_loss= 0.68332 train_acc= 0.47500 val_loss= 0.69911 val_acc= 0.40000 time= 0.01061
# Cross-val iter: 09 epoch: 004 train_loss= 0.68390 train_acc= 0.55000 val_loss= 0.70071 val_acc= 0.40000 time= 0.00959
# Cross-val iter: 09 epoch: 005 train_loss= 0.67898 train_acc= 0.52500 val_loss= 0.73912 val_acc= 0.40000 time= 0.01004
# Optimization finished!
# Loading checkpoint!
# test_loss= 0.66054 test_acc= 0.80000
#
# Cross-val iter: 10 epoch: 001 train_loss= 0.68455 train_acc= 0.52500 val_loss= 15.16233 val_acc= 0.20000 time= 0.01524
# Cross-val iter: 10 epoch: 002 train_loss= 0.68423 train_acc= 0.45000 val_loss= 12.23248 val_acc= 0.20000 time= 0.01173
# Cross-val iter: 10 epoch: 003 train_loss= 0.68459 train_acc= 0.50000 val_loss= 9.98923 val_acc= 0.20000 time= 0.01176
# Cross-val iter: 10 epoch: 004 train_loss= 0.67832 train_acc= 0.55000 val_loss= 8.38110 val_acc= 0.20000 time= 0.01012
# Cross-val iter: 10 epoch: 005 train_loss= 0.68942 train_acc= 0.45000 val_loss= 7.09063 val_acc= 0.20000 time= 0.01369
# Optimization finished!
# Loading checkpoint!
# test_loss= 3.54539 test_acc= 0.60000
#
# avg_test_acc= 0.54000

# %%
adjacency_lists = model.get_hidden_graphs_adjacency_list()

# Print the adjacency lists for each hidden graph
for i, adj_list in enumerate(adjacency_lists):
    print(f"Hidden Graph {i}:")
    for node, neighbors in adj_list.items():
        print(f"  Node {node}: {neighbors}")
# Out:
# Hidden Graph 0:
#   Node 0: [2, 3, 4]
#   Node 1: [2, 3]
#   Node 2: [0, 1]
#   Node 3: [0, 1, 4]
#   Node 4: [0, 3]
# Hidden Graph 1:
#   Node 0: [3, 4]
#   Node 1: [2]
#   Node 2: [1, 4]
#   Node 3: [0, 4]
#   Node 4: [0, 2, 3]
# Hidden Graph 2:
#   Node 0: [4]
#   Node 1: [2, 3]
#   Node 2: [1, 4]
#   Node 3: [1]
#   Node 4: [0, 2]
# Hidden Graph 3:
#   Node 0: [1, 3]
#   Node 1: [0, 3, 4]
#   Node 2: [3]
#   Node 3: [0, 1, 2]
#   Node 4: [1]
# Hidden Graph 4:
#   Node 0: [3, 4]
#   Node 1: [3]
#   Node 2: []
#   Node 3: [0, 1, 4]
#   Node 4: [0, 3]
# Hidden Graph 5:
#   Node 0: [1, 2, 3]
#   Node 1: [0]
#   Node 2: [0, 3]
#   Node 3: [0, 2]
#   Node 4: []
# Hidden Graph 6:
#   Node 0: [1, 2, 4]
#   Node 1: [0, 4]
#   Node 2: [0, 3]
#   Node 3: [2]
#   Node 4: [0, 1]
# Hidden Graph 7:
#   Node 0: [2, 3, 4]
#   Node 1: [2]
#   Node 2: [0, 1, 4]
#   Node 3: [0, 4]
#   Node 4: [0, 2, 3]
# Hidden Graph 8:
#   Node 0: [3, 4]
#   Node 1: [3, 4]
#   Node 2: []
#   Node 3: [0, 1]
#   Node 4: [0, 1]
# Hidden Graph 9:
#   Node 0: [2, 3]
#   Node 1: [4]
#   Node 2: [0, 4]
#   Node 3: [0]
#   Node 4: [1, 2]
# Hidden Graph 10:
#   Node 0: []
#   Node 1: [2, 3]
#   Node 2: [1, 3, 4]
#   Node 3: [1, 2, 4]
#   Node 4: [2, 3]
# Hidden Graph 11:
#   Node 0: [2, 3]
#   Node 1: [4]
#   Node 2: [0, 3]
#   Node 3: [0, 2]
#   Node 4: [1]
# Hidden Graph 12:
#   Node 0: [1, 2]
#   Node 1: [0, 3, 4]
#   Node 2: [0, 4]
#   Node 3: [1]
#   Node 4: [1, 2]
# Hidden Graph 13:
#   Node 0: [1, 2]
#   Node 1: [0, 2, 3]
#   Node 2: [0, 1, 4]
#   Node 3: [1]
#   Node 4: [2]
# Hidden Graph 14:
#   Node 0: [2]
#   Node 1: [2, 4]
#   Node 2: [0, 1, 3, 4]
#   Node 3: [2]
#   Node 4: [1, 2]
# Hidden Graph 15:
#   Node 0: []
#   Node 1: [4]
#   Node 2: [4]
#   Node 3: [4]
#   Node 4: [1, 2, 3]

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Assuming model is defined and adjacency lists are obtained as follows:
adjacency_lists = model.get_hidden_graphs_adjacency_list()

# Draw the adjacency list as a graph using NetworkX and Matplotlib
for i, adj_list in enumerate(adjacency_lists):
    G = nx.Graph()  # Create a new graph
    # Add edges to the graph based on the adjacency list
    for node, neighbors in adj_list.items():
        for neighbor in neighbors:
            G.add_edge(node, neighbor)

    # Draw the graph
    plt.figure(figsize=(8, 6))
    pos = nx.spring_layout(G)  # Positioning the nodes using the spring layout
    nx.draw(G, pos, with_labels=True, node_size=500, node_color='skyblue', font_size=10, font_weight='bold', edge_color='gray')
    plt.title(f"Hidden Graph {i}")
    plt.show()

# %%
# THE MODEL
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.autograd import Variable
from torch.nn.parameter import Parameter

class RW_NN(nn.Module):
    # new hyperparameters
    # max_num_children
    def __init__(self, input_dim, max_step, hidden_graphs, size_hidden_graphs, hidden_dim, penultimate_dim, normalize, n_classes, dropout, device):
        super(RW_NN, self).__init__()
        self.max_step = max_step
        self.hidden_graphs = hidden_graphs
        self.size_hidden_graphs = size_hidden_graphs
        self.normalize = normalize
        self.device = device
        self.adj_hidden = Parameter(torch.FloatTensor(hidden_graphs, (size_hidden_graphs*(size_hidden_graphs-1))//2))
        self.features_hidden = Parameter(torch.FloatTensor(hidden_graphs, size_hidden_graphs, hidden_dim))
        self.fc = torch.nn.Linear(input_dim, hidden_dim)
        self.bn = nn.BatchNorm1d(hidden_graphs*max_step)
        self.fc1 = torch.nn.Linear(hidden_graphs*max_step, penultimate_dim)
        self.fc2 = torch.nn.Linear(penultimate_dim, n_classes)
        self.dropout = nn.Dropout(p=dropout)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()
        self.init_weights()

    def init_weights(self):
        self.adj_hidden.data.uniform_(-1, 1)
        self.features_hidden.data.uniform_(0, 1)

        
    def forward(self, adj, features, graph_indicator):
        unique, counts = torch.unique(graph_indicator, return_counts=True)
        n_graphs = unique.size(0)
        n_nodes = features.size(0)

        if self.normalize:
            norm = counts.unsqueeze(1).repeat(1, self.hidden_graphs)
        
        adj_hidden_norm = torch.zeros(self.hidden_graphs, self.size_hidden_graphs, self.size_hidden_graphs).to(self.device)
        idx = torch.triu_indices(self.size_hidden_graphs, self.size_hidden_graphs, 1)
        adj_hidden_norm[:,idx[0],idx[1]] = self.relu(self.adj_hidden)
        adj_hidden_norm = adj_hidden_norm + torch.transpose(adj_hidden_norm, 1, 2)
        x = self.sigmoid(self.fc(features))
        z = self.features_hidden
        zx = torch.einsum("abc,dc->abd", (z, x))
        
        out = list()
        for i in range(self.max_step):
            if i == 0:
                eye = torch.eye(self.size_hidden_graphs, device=self.device)
                eye = eye.repeat(self.hidden_graphs, 1, 1)              
                o = torch.einsum("abc,acd->abd", (eye, z))
                t = torch.einsum("abc,dc->abd", (o, x))
            else:
                x = torch.spmm(adj, x)
                z = torch.einsum("abc,acd->abd", (adj_hidden_norm, z))
                t = torch.einsum("abc,dc->abd", (z, x))
            t = self.dropout(t)
            t = torch.mul(zx, t)
            t = torch.zeros(t.size(0), t.size(1), n_graphs, device=self.device).index_add_(2, graph_indicator, t)
            t = torch.sum(t, dim=1)
            t = torch.transpose(t, 0, 1)
            if self.normalize:
                t /= norm
            out.append(t)
            
        out = torch.cat(out, dim=1)
        out = self.bn(out)
        out = self.relu(self.fc1(out))
        out = self.dropout(out)
        out = self.fc2(out)
        return F.log_softmax(out, dim=1)
    def get_hidden_graphs_adjacency_list(self):
        """Converts the upper-triangular adjacency data to adjacency lists."""
        adj_hidden_norm = torch.zeros(self.hidden_graphs, self.size_hidden_graphs, self.size_hidden_graphs).to(self.device)
        idx = torch.triu_indices(self.size_hidden_graphs, self.size_hidden_graphs, 1)
        adj_hidden_norm[:, idx[0], idx[1]] = self.relu(self.adj_hidden)
        adj_hidden_norm = adj_hidden_norm + torch.transpose(adj_hidden_norm, 1, 2)
        
        # Convert each hidden graph's adjacency matrix to an adjacency list
        adjacency_lists = []
        for i in range(self.hidden_graphs):
            adj_list = {}
            adj_matrix = adj_hidden_norm[i].detach().cpu().numpy()  # Move to CPU for easy processing
            for row in range(adj_matrix.shape[0]):
                adj_list[row] = list(np.where(adj_matrix[row] > 0)[0])  # Find connected nodes
            adjacency_lists.append(adj_list)
        
        return adjacency_lists

# %%
import matplotlib.pyplot as plt
import networkx as nx
import random

open("graph_A.txt", "w").close()

open("graph_indicator.txt", "w").close()
open("graph_labels.txt", "w").close()
graph_indicator = 1
random_num = random.randint(5, 30)
random_graphs = []
for _ in range(25):
    n = random_num  # 10 nodes
    m = random_num  # 20 edges
    # seed = 42  # seed random number generators for reproducibility

    # Use seed for reproducibility
    G = nx.gnm_random_graph(n, m)
    random_graphs.append(G)
    # some properties
    # print("node degree clustering")
    # for v in nx.nodes(G):
    #     print(f"{v} {nx.degree(G, v)} {nx.clustering(G, v)}")

    # print()
    print(nx.generate_adjlist(G))
    pairs = []

    for line in nx.generate_adjlist(G):
        # Split the line into nodes
        nodes = line.split()
        # The first node is the source, and the rest are targets
        source = nodes[0]
        targets = nodes[1:]
        
        # Generate (source, target) pairs
        for target in targets:
            print(str(int(source) + 1))
            pairs.append((str(int(source) + 1), str(int(target) + 1)))
    print(pairs)
    # Write the result to a file
    with open("graph_A.txt", "a") as f:
        for pair in pairs:
            f.write(f"{pair[0]}, {pair[1]}\n")

    with open("graph_indicator.txt", "a") as f:
        for pair in pairs:
            f.write(f"{graph_indicator}\n")
    with open("graph_labels.txt", "a") as f:
        f.write(f"0\n")
        graph_indicator += 1
# Out:
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 2
# 3
# 3
# 4
# 6
# 7
# [('1', '3'), ('1', '4'), ('2', '7'), ('3', '4'), ('3', '7'), ('4', '6'), ('6', '7'), ('7', '8')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 2
# 2
# 3
# 3
# 4
# 6
# [('1', '2'), ('1', '8'), ('2', '5'), ('2', '6'), ('3', '6'), ('3', '7'), ('4', '8'), ('6', '8')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 2
# 3
# 4
# 4
# 5
# 6
# 6
# [('1', '3'), ('2', '6'), ('3', '7'), ('4', '7'), ('4', '5'), ('5', '8'), ('6', '7'), ('6', '8')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 3
# 4
# 4
# 5
# 5
# 7
# [('1', '4'), ('1', '3'), ('3', '4'), ('4', '5'), ('4', '6'), ('5', '6'), ('5', '7'), ('7', '8')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 2
# 3
# 3
# 4
# 5
# 5
# [('1', '2'), ('1', '3'), ('2', '7'), ('3', '7'), ('3', '5'), ('4', '6'), ('5', '6'), ('5', '8')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 2
# 3
# 5
# 5
# 6
# 6
# [('1', '3'), ('1', '2'), ('2', '5'), ('3', '6'), ('5', '6'), ('5', '7'), ('6', '7'), ('6', '8')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 2
# 2
# 3
# 3
# 3
# 4
# 4
# 6
# [('2', '4'), ('2', '7'), ('3', '5'), ('3', '6'), ('3', '7'), ('4', '6'), ('4', '7'), ('6', '7')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 2
# 3
# 4
# 4
# 5
# 7
# [('1', '3'), ('1', '5'), ('2', '6'), ('3', '5'), ('4', '5'), ('4', '8'), ('5', '6'), ('7', '8')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 1
# 3
# 4
# 4
# 5
# 6
# [('1', '7'), ('1', '5'), ('1', '3'), ('3', '8'), ('4', '6'), ('4', '7'), ('5', '8'), ('6', '7')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 2
# 2
# 4
# 4
# 6
# 6
# [('1', '8'), ('1', '7'), ('2', '3'), ('2', '8'), ('4', '6'), ('4', '8'), ('6', '8'), ('6', '7')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 1
# 2
# 4
# 4
# 5
# 7
# [('1', '4'), ('1', '6'), ('1', '7'), ('2', '5'), ('4', '7'), ('4', '8'), ('5', '6'), ('7', '8')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 1
# 1
# 2
# 3
# 4
# 7
# [('1', '4'), ('1', '2'), ('1', '8'), ('1', '6'), ('2', '3'), ('3', '8'), ('4', '8'), ('7', '8')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 1
# 3
# 3
# 4
# 6
# 7
# [('1', '3'), ('1', '6'), ('1', '5'), ('3', '4'), ('3', '6'), ('4', '8'), ('6', '7'), ('7', '8')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 2
# 4
# 4
# 4
# 5
# 6
# [('1', '8'), ('1', '2'), ('2', '4'), ('4', '7'), ('4', '5'), ('4', '6'), ('5', '7'), ('6', '8')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 2
# 2
# 2
# 3
# 4
# 5
# 6
# [('1', '3'), ('2', '8'), ('2', '4'), ('2', '3'), ('3', '8'), ('4', '5'), ('5', '8'), ('6', '8')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 2
# 2
# 3
# 4
# 4
# 5
# [('1', '5'), ('1', '6'), ('2', '5'), ('2', '8'), ('3', '6'), ('4', '6'), ('4', '5'), ('5', '6')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 1
# 4
# 4
# 6
# 6
# 7
# [('1', '5'), ('1', '2'), ('1', '6'), ('4', '5'), ('4', '8'), ('6', '8'), ('6', '7'), ('7', '8')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 2
# 3
# 4
# 5
# 5
# 6
# [('1', '6'), ('1', '3'), ('2', '4'), ('3', '6'), ('4', '8'), ('5', '6'), ('5', '7'), ('6', '7')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 1
# 2
# 3
# 4
# 5
# 5
# [('1', '6'), ('1', '8'), ('1', '4'), ('2', '4'), ('3', '8'), ('4', '8'), ('5', '7'), ('5', '6')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 2
# 2
# 3
# 4
# 4
# 5
# 6
# [('1', '8'), ('2', '7'), ('2', '5'), ('3', '7'), ('4', '8'), ('4', '6'), ('5', '6'), ('6', '8')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 1
# 2
# 3
# 5
# 5
# 5
# [('1', '6'), ('1', '7'), ('1', '2'), ('2', '8'), ('3', '5'), ('5', '7'), ('5', '8'), ('5', '6')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 2
# 2
# 3
# 3
# 4
# 4
# 5
# [('1', '4'), ('2', '7'), ('2', '3'), ('3', '4'), ('3', '5'), ('4', '5'), ('4', '7'), ('5', '8')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 1
# 1
# 1
# 1
# 2
# 4
# [('1', '8'), ('1', '3'), ('1', '7'), ('1', '6'), ('1', '4'), ('1', '5'), ('2', '3'), ('4', '5')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 1
# 1
# 2
# 2
# 4
# 5
# 6
# [('1', '7'), ('1', '4'), ('1', '2'), ('2', '4'), ('2', '5'), ('4', '5'), ('5', '7'), ('6', '7')]
# <generator object generate_adjlist at 0x000001B87E8CF4C0>
# 1
# 2
# 2
# 2
# 2
# 4
# 6
# 7
# [('1', '4'), ('2', '3'), ('2', '5'), ('2', '8'), ('2', '4'), ('4', '6'), ('6', '8'), ('7', '8')]

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
for train_index, test_index in kf.split(y):
    it += 1
    
    idx = np.random.permutation(train_index)
    train_index = idx[:int(idx.size*0.9)].tolist()
    val_index = idx[int(idx.size*0.9):].tolist()

    n_train = len(train_index)
    n_val = len(val_index)
    n_test = len(test_index)

    adj_train = [adj_lst[i] for i in train_index]
    features_train = [features_lst[i] for i in train_index]
    y_train = [y[i] for i in train_index]

    adj_val = [adj_lst[i] for i in val_index]
    features_val = [features_lst[i] for i in val_index]
    y_val = [y[i] for i in val_index]

    adj_test = [adj_lst[i] for i in test_index]
    features_test = [features_lst[i] for i in test_index]
    y_test = [y[i] for i in test_index]

    adj_train, features_train, graph_indicator_train, y_train = generate_batches(adj_train, features_train, y_train, args.batch_size, device)
    adj_val, features_val, graph_indicator_val, y_val = generate_batches(adj_val, features_val, y_val, args.batch_size, device)
    adj_test, features_test, graph_indicator_test, y_test = generate_batches(adj_test, features_test, y_test, args.batch_size, device)

    n_train_batches = ceil(n_train/args.batch_size)
    n_val_batches = ceil(n_val/args.batch_size)
    n_test_batches = ceil(n_test/args.batch_size)
    
    model = RW_NN(features_dim, args.max_step, args.hidden_graphs, args.size_hidden_graphs, args.hidden_dim, args.penultimate_dim, args.normalize, n_classes, args.dropout, device).to(device)
    optimizer = optim.Adam(model.parameters(), lr=args.lr)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.5)

    def train(epoch, adj, features, graph_indicator, y):
        optimizer.zero_grad()
        output = model(adj, features, graph_indicator)
        loss_train = F.cross_entropy(output, y)
        loss_train.backward()
        optimizer.step()
        return output, loss_train

    def test(adj, features, graph_indicator, y):
        output = model(adj, features, graph_indicator)
        loss_test = F.cross_entropy(output, y)
        return output, loss_test

    best_acc = 0

    for epoch in range(args.epochs):
        start = time.time()
        model.train()
        train_loss = AverageMeter()
        train_acc = AverageMeter()

        # Train for one epoch
        for i in range(n_train_batches):
            output, loss = train(epoch, adj_train[i], features_train[i], graph_indicator_train[i], y_train[i])
            train_loss.update(loss.item(), output.size(0))
            train_acc.update(accuracy(output.data, y_train[i].data), output.size(0))

        # Evaluate on validation set
        model.eval()
        val_loss = AverageMeter()
        val_acc = AverageMeter()

        for i in range(n_val_batches):
            output, loss = test(adj_val[i], features_val[i], graph_indicator_val[i], y_val[i])
            val_loss.update(loss.item(), output.size(0))
            val_acc.update(accuracy(output.data, y_val[i].data), output.size(0))

        scheduler.step()
        
        # Print results
        print("Cross-val iter:", '%02d' % it, "epoch:", '%03d' % (epoch + 1), "train_loss=", "{:.5f}".format(train_loss.avg),
            "train_acc=", "{:.5f}".format(train_acc.avg), "val_loss=", "{:.5f}".format(val_loss.avg),
            "val_acc=", "{:.5f}".format(val_acc.avg), "time=", "{:.5f}".format(time.time() - start))
        
        # Remember best accuracy and save checkpoint
        is_best = val_acc.avg >= best_acc
        best_acc = max(val_acc.avg, best_acc)
        if is_best:
            early_stopping_counter = 0
            torch.save({
                'epoch': epoch + 1,
                'state_dict': model.state_dict(),
                'optimizer' : optimizer.state_dict(),
            }, 'model_best.pth.tar')

    print("Optimization finished!")

    # Testing
    test_loss = AverageMeter()
    test_acc = AverageMeter()
    print("Loading checkpoint!")
    checkpoint = torch.load('model_best.pth.tar')
    epoch = checkpoint['epoch']
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    
    for i in range(n_test_batches):
        output, loss = test(adj_test[i], features_test[i], graph_indicator_test[i], y_test[i])
        test_loss.update(loss.item(), output.size(0))
        test_acc.update(accuracy(output.data, y_test[i].data), output.size(0))
    accs.append(test_acc.avg.cpu().numpy())

    # Print results
    print("test_loss=", "{:.5f}".format(test_loss.avg), "test_acc=", "{:.5f}".format(test_acc.avg))
    print()
    
print("avg_test_acc=", "{:.5f}".format(np.mean(accs)))
# Out:
# Cross-val iter: 01 epoch: 001 train_loss= 0.70514 train_acc= 0.47500 val_loss= 6.03941 val_acc= 0.80000 time= 0.02884
# Cross-val iter: 01 epoch: 002 train_loss= 0.66877 train_acc= 0.62500 val_loss= 3.50872 val_acc= 0.80000 time= 0.01623
# Cross-val iter: 01 epoch: 003 train_loss= 0.69184 train_acc= 0.47500 val_loss= 2.32076 val_acc= 0.80000 time= 0.01068
# Cross-val iter: 01 epoch: 004 train_loss= 0.69550 train_acc= 0.47500 val_loss= 1.60473 val_acc= 0.80000 time= 0.01146
# Cross-val iter: 01 epoch: 005 train_loss= 0.71536 train_acc= 0.42500 val_loss= 1.20544 val_acc= 0.80000 time= 0.01519
# Optimization finished!
# Loading checkpoint!
# test_loss= 75.54613 test_acc= 0.40000
#
# Cross-val iter: 02 epoch: 001 train_loss= 0.74745 train_acc= 0.50000 val_loss= 1.48873 val_acc= 0.40000 time= 0.00566
# Cross-val iter: 02 epoch: 002 train_loss= 0.68957 train_acc= 0.52500 val_loss= 1.70970 val_acc= 0.40000 time= 0.01340
# Cross-val iter: 02 epoch: 003 train_loss= 0.68211 train_acc= 0.52500 val_loss= 1.78178 val_acc= 0.40000 time= 0.00951
# Cross-val iter: 02 epoch: 004 train_loss= 0.67612 train_acc= 0.47500 val_loss= 1.75070 val_acc= 0.40000 time= 0.02173
# Cross-val iter: 02 epoch: 005 train_loss= 0.67795 train_acc= 0.45000 val_loss= 1.67282 val_acc= 0.40000 time= 0.00000
# Optimization finished!
# Loading checkpoint!
# test_loss= 1.13738 test_acc= 0.60000
#
# Cross-val iter: 03 epoch: 001 train_loss= 0.67959 train_acc= 0.55000 val_loss= 0.99157 val_acc= 0.20000 time= 0.02051
# Cross-val iter: 03 epoch: 002 train_loss= 0.67648 train_acc= 0.52500 val_loss= 2.02506 val_acc= 0.20000 time= 0.00859
# Cross-val iter: 03 epoch: 003 train_loss= 0.68024 train_acc= 0.52500 val_loss= 2.66181 val_acc= 0.20000 time= 0.01368
# Cross-val iter: 03 epoch: 004 train_loss= 0.68096 train_acc= 0.47500 val_loss= 2.83137 val_acc= 0.20000 time= 0.01869
# Cross-val iter: 03 epoch: 005 train_loss= 0.67656 train_acc= 0.55000 val_loss= 2.84599 val_acc= 0.20000 time= 0.01101
# Optimization finished!
# Loading checkpoint!
# test_loss= 1.43757 test_acc= 0.60000
#
# Cross-val iter: 04 epoch: 001 train_loss= 0.73515 train_acc= 0.40000 val_loss= 1.25535 val_acc= 0.20000 time= 0.01426
# Cross-val iter: 04 epoch: 002 train_loss= 0.69450 train_acc= 0.37500 val_loss= 0.64587 val_acc= 0.80000 time= 0.01564
# Cross-val iter: 04 epoch: 003 train_loss= 0.67568 train_acc= 0.57500 val_loss= 0.62638 val_acc= 0.80000 time= 0.00054
# Cross-val iter: 04 epoch: 004 train_loss= 0.66341 train_acc= 0.62500 val_loss= 0.90329 val_acc= 0.20000 time= 0.01231
# Cross-val iter: 04 epoch: 005 train_loss= 0.66846 train_acc= 0.65000 val_loss= 1.12118 val_acc= 0.20000 time= 0.00500
# Optimization finished!
# Loading checkpoint!
# test_loss= 0.67601 test_acc= 0.60000
#
# Cross-val iter: 05 epoch: 001 train_loss= 0.70238 train_acc= 0.52500 val_loss= 0.87302 val_acc= 0.60000 time= 0.00904
# Cross-val iter: 05 epoch: 002 train_loss= 0.68487 train_acc= 0.45000 val_loss= 1.09110 val_acc= 0.40000 time= 0.01351
# Cross-val iter: 05 epoch: 003 train_loss= 0.67941 train_acc= 0.47500 val_loss= 1.47796 val_acc= 0.40000 time= 0.02016
# Cross-val iter: 05 epoch: 004 train_loss= 0.68088 train_acc= 0.55000 val_loss= 1.83832 val_acc= 0.40000 time= 0.02417
# Cross-val iter: 05 epoch: 005 train_loss= 0.67914 train_acc= 0.55000 val_loss= 2.06884 val_acc= 0.40000 time= 0.01563
# Optimization finished!
# Loading checkpoint!
# test_loss= 0.87302 test_acc= 0.60000
#
# Cross-val iter: 06 epoch: 001 train_loss= 0.75059 train_acc= 0.47500 val_loss= 3.06768 val_acc= 0.60000 time= 0.00000
# Cross-val iter: 06 epoch: 002 train_loss= 0.69196 train_acc= 0.52500 val_loss= 2.13719 val_acc= 0.60000 time= 0.01563
# Cross-val iter: 06 epoch: 003 train_loss= 0.67245 train_acc= 0.52500 val_loss= 1.47929 val_acc= 0.60000 time= 0.00651
# Cross-val iter: 06 epoch: 004 train_loss= 0.71876 train_acc= 0.37500 val_loss= 1.14274 val_acc= 0.60000 time= 0.01563
# Cross-val iter: 06 epoch: 005 train_loss= 0.63011 train_acc= 0.75000 val_loss= 0.84779 val_acc= 0.60000 time= 0.01953
# Optimization finished!
# Loading checkpoint!
# test_loss= 0.84779 test_acc= 0.60000
#
# Cross-val iter: 07 epoch: 001 train_loss= 0.67821 train_acc= 0.60000 val_loss= 2.46869 val_acc= 0.60000 time= 0.00824
# Cross-val iter: 07 epoch: 002 train_loss= 0.67412 train_acc= 0.62500 val_loss= 2.93422 val_acc= 0.60000 time= 0.00000
# Cross-val iter: 07 epoch: 003 train_loss= 0.67548 train_acc= 0.47500 val_loss= 3.09171 val_acc= 0.60000 time= 0.01727
# Cross-val iter: 07 epoch: 004 train_loss= 0.69042 train_acc= 0.45000 val_loss= 2.77270 val_acc= 0.60000 time= 0.01705
# Cross-val iter: 07 epoch: 005 train_loss= 0.67607 train_acc= 0.60000 val_loss= 2.33667 val_acc= 0.60000 time= 0.01354
# Optimization finished!
# Loading checkpoint!
# test_loss= 3.50354 test_acc= 0.40000
#
# Cross-val iter: 08 epoch: 001 train_loss= 0.72746 train_acc= 0.57500 val_loss= 1.78049 val_acc= 0.60000 time= 0.01906
# Cross-val iter: 08 epoch: 002 train_loss= 0.66729 train_acc= 0.57500 val_loss= 2.05833 val_acc= 0.60000 time= 0.01629
# Cross-val iter: 08 epoch: 003 train_loss= 0.67956 train_acc= 0.57500 val_loss= 2.18216 val_acc= 0.60000 time= 0.00000
# Cross-val iter: 08 epoch: 004 train_loss= 0.68476 train_acc= 0.45000 val_loss= 2.15833 val_acc= 0.60000 time= 0.01195
# Cross-val iter: 08 epoch: 005 train_loss= 0.66640 train_acc= 0.55000 val_loss= 2.08122 val_acc= 0.60000 time= 0.01838
# Optimization finished!
# Loading checkpoint!
# test_loss= 2.08122 test_acc= 0.60000
#
# Cross-val iter: 09 epoch: 001 train_loss= 0.69436 train_acc= 0.55000 val_loss= 3.00319 val_acc= 0.60000 time= 0.01351
# Cross-val iter: 09 epoch: 002 train_loss= 0.66276 train_acc= 0.60000 val_loss= 0.99690 val_acc= 0.60000 time= 0.00000
# Cross-val iter: 09 epoch: 003 train_loss= 0.69548 train_acc= 0.37500 val_loss= 0.67597 val_acc= 0.60000 time= 0.01451
# Cross-val iter: 09 epoch: 004 train_loss= 0.67340 train_acc= 0.55000 val_loss= 0.67760 val_acc= 0.60000 time= 0.00715
# Cross-val iter: 09 epoch: 005 train_loss= 0.68688 train_acc= 0.47500 val_loss= 0.70023 val_acc= 0.60000 time= 0.01817
# Optimization finished!
# Loading checkpoint!
# test_loss= 1.05687 test_acc= 0.20000
#
# Cross-val iter: 10 epoch: 001 train_loss= 0.73223 train_acc= 0.35000 val_loss= 0.50075 val_acc= 0.80000 time= 0.01338
# Cross-val iter: 10 epoch: 002 train_loss= 0.68397 train_acc= 0.57500 val_loss= 1.08140 val_acc= 0.20000 time= 0.01213
# Cross-val iter: 10 epoch: 003 train_loss= 0.68624 train_acc= 0.50000 val_loss= 1.89721 val_acc= 0.20000 time= 0.00531
# Cross-val iter: 10 epoch: 004 train_loss= 0.67743 train_acc= 0.55000 val_loss= 2.40391 val_acc= 0.20000 time= 0.00000
# Cross-val iter: 10 epoch: 005 train_loss= 0.67070 train_acc= 0.62500 val_loss= 2.59156 val_acc= 0.20000 time= 0.01149
# Optimization finished!
# Loading checkpoint!
# test_loss= 1.02921 test_acc= 0.40000
#
# avg_test_acc= 0.50000

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Assuming model is defined and adjacency lists are obtained as follows:
adjacency_lists = model.get_hidden_graphs_adjacency_list()

# Draw the adjacency list as a graph using NetworkX and Matplotlib
for i, adj_list in enumerate(adjacency_lists):
    G = nx.Graph()  # Create a new graph
    # Add edges to the graph based on the adjacency list
    for node, neighbors in adj_list.items():
        for neighbor in neighbors:
            G.add_edge(node, neighbor)

    # Draw the graph
    plt.figure(figsize=(8, 6))
    pos = nx.spring_layout(G)  # Positioning the nodes using the spring layout
    nx.draw(G, pos, with_labels=True, node_size=500, node_color='skyblue', font_size=10, font_weight='bold', edge_color='gray')
    plt.title(f"Hidden Graph {i}")
    plt.show()
